# %%
import numpy as np
import pandas as

# %%
raw_data = np.genfromtxt('data/189_2011.txt', skip_header=14, delimiter=';', dtype=(str, float, int))

# %%
import pandas as pd
a=pd.to_datetime(['07/09/2011 09:00:00', '07/09/2011 09:00:00'])

# %%
a
# Out:
# DatetimeIndex(['2011-07-09 09:00:00', '2011-07-09 09:00:00'], dtype='datetime64[ns]', freq=None)

# %%
with open('data/189_2011.txt') as f:
    raw_data = f.readlines()

# %%
raw_data
# Out:
# array([('', 3.64 , 1), ('', 4.19 , 1), ('', 4.225, 1), ...,
#        ('', 4.149, 2), ('', 4.071, 3), ('', 4.071, 2)],
#       dtype=[('f0', '<U'), ('f1', '<f8'), ('f2', '<i8')])

# %%
raw_data
# Out:
# ['# Station : ILE_D_AIX\n',
#  '# Longitude : -1.174341\n',
#  '# Latitude : 46.007357\n',
#  '# Organisme fournisseur de données : Shom, LIENSs, Charente Maritime\n',
#  '# Fuseau horaire : UTC\n',
#  '# Référence verticale : zero_hydrographique\n',
#  '# Unité : m\n',
#  '# Source 1 : Données brutes temps réel\n',
#  '# Source 2 : Données brutes temps différé\n',
#  '# Source 3 : Données validées temps différé\n',
#  '# Source 4 : Données horaires validées\n',
#  '# Source 5 : Données horaires brutes\n',
#  '# Source 6 : Pleines et basses mers\n',
#  '# Date;Valeur;Source\n',
#  '07/09/2011 08:57:20;3.64;1\n',
#  '07/09/2011 08:58:20;4.19;1\n',
#  '07/09/2011 08:59:20;4.225;1\n',
#  '07/09/2011 09:00:00;4.169;4\n',
#  '07/09/2011 09:00:00;4.209;2\n',
#  '07/09/2011 09:00:20;4.215;1\n',
#  '07/09/2011 09:01:20;4.221;1\n',
#  '07/09/2011 09:02:20;4.25;1\n',
#  '07/09/2011 09:03:20;4.22;1\n',
#  '07/09/2011 09:04:20;4.226;1\n',
#  '07/09/2011 09:05:20;4.223;1\n',
# ...
